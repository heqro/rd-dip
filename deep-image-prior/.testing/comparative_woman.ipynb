# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fftpack import dct, idct
import torch
import torch.nn.functional as F
from PIL import Image
import numpy as np

import sys
sys.path.append('../')
from _utils import grads, derivative5, derivative7

# %% [markdown]
# Load the image and convert to `PyTorch` tensor

# %%
image_path = "/mnt/data_drive/hrodrigo/mri_rician_noise/deep-image-prior/oldyoungwoman.png"  # subject_04_Std0.15.png
img = Image.open(image_path).convert("L")
img_tensor = torch.FloatTensor(np.array(img)[None, ...])  # CxHxW
img_tensor = img_tensor[None, ...] # add batch dimension

# %% [markdown]
# Apply convolutions and do away with batch dimension

# %%
dx,dy=grads(img_tensor)

# %%
_, axs = plt.subplots(1, 4, figsize=(20,20))

axs[0].axis('off')
axs[0].imshow(img,cmap='gray')

axs[1].axis('off')
axs[1].imshow(dx.squeeze(), cmap='gray')

axs[2].axis('off')
axs[2].imshow(dy.squeeze(), cmap='gray')

axs[3].imshow(np.sqrt(dx**2+dy**2).squeeze(), cmap='gray')
axs[3].axis('off')
# Out:
# (-0.5, 899.5, 1234.5, -0.5)

# %%
dx,dy=derivative5(img_tensor)

# %%
_, axs = plt.subplots(1, 4, figsize=(20,20))

axs[0].axis('off')
axs[0].imshow(img,cmap='gray')

axs[1].axis('off')
axs[1].imshow(dx.squeeze(), cmap='gray')

axs[2].axis('off')
axs[2].imshow(dy.squeeze(), cmap='gray')

axs[3].imshow(np.sqrt(dx**2+dy**2).squeeze(), cmap='gray')
axs[3].axis('off')
# Out:
# (-0.5, 899.5, 1234.5, -0.5)

# %%
dx,dy=derivative7(img_tensor)

# %%
_, axs = plt.subplots(1, 4, figsize=(20,20))

axs[0].axis('off')
axs[0].imshow(img,cmap='gray')

axs[1].axis('off')
axs[1].imshow(dx.squeeze(), cmap='gray')

axs[2].axis('off')
axs[2].imshow(dy.squeeze(), cmap='gray')

axs[3].imshow(np.sqrt(dx**2+dy**2).squeeze(), cmap='gray')
axs[3].axis('off')
# Out:
# (-0.5, 899.5, 1234.5, -0.5)
